# %% [markdown]
# # Wahldaten-Crawler für alle Bundestags-, Landtags- und Europawahlen
# Dieses Skript lädt Wahlergebnisse für alle Wahlen in Deutschland aus dem [Wahlarchiv der Tagesschau](https://wahl.tagesschau.de/wahlen/chronologie/chronologie.shtml) herunter. Diese werden in einem JSON-Format im aktuellen Verzeichnis gespeichert.
#
# Das Ausgabeformat ist eine Liste mit Objekten. Jedes Objekt hat folgende Felder:
#
# | Feld       | Beschreibung                                              |
# |------------|-----------------------------------------------------------|
# | title      | Titel der Wahl, z.B. Bundestagswahl 1990                  |
# | url        | URL der Quelle                                            |
# | date       | Datum der Wahl in ISO-8601                                |
# | territory  | Bundesland, "Deutschland", "BRD", "DDR", oder "Europa"    |
# | kind       | Art der Wahl, z.B. Landtagswahl                           |
# | government | Liste der Parteien, die die Regierung stellen, als Kürzel |
# | turnout    | Wahlbeteiligung in Prozent (optional)                     |
# | results    | Wahlergebnisse der einzelnen Parteien                     |
#
# Das Feld `results` enthält ein Objekt mit einem Schlüssel für jedes Parteikürzel. Der Wert ist jeweils ein Objekt mit folgenden Feldern:
#
# | Feld      | Beschreibung                                        |
# |-----------|-----------------------------------------------------|
# | pct       | Wahlergebnis mit ein oder zwei Nachkommastellen     |
# | votes     | Anzahl Stimmen (optional)                           |
# | long_name | Voller Name oder Beschreibung der Partei (optional) |
# | color     | Hexcode der Parteifarbe (optional)                  |

# %% [markdown]
# ## Quellcode
#
# Zunächst wird aus einer Übersichtsseite eine Liste der URLs aller Wahl-Seiten generiert.

# %%
import requests
from bs4 import BeautifulSoup

URL_BASE = "https://wahl.tagesschau.de/wahlen/"

overview_raw = requests.get(URL_BASE + "chronologie/chronologie.shtml")
page = BeautifulSoup(overview_raw.content, 'html.parser')

election_urls = []
for listing in page.find_all('ul', {"class": "list"}):
    for entry in listing.find_all('a'):
        election_urls.append({
            "title": entry.text,
            "url": URL_BASE + entry["href"][3:]
        })
        
print(f"Found {len(election_urls)} elections")
# Out:
# Found 270 elections

# %% [markdown]
# Als nächstes werden die Wahlseiten jeder Wahl geladen und die Wahlergebnisse und Metadaten extrahiert. Mehrere Hilfs-Funktionen extrahieren Metadaten aus der Seite.

# %%
import json
from datetime import datetime
from time import sleep

DATE_FORMAT = "%d.%m.%Y"
TIMESTAMP = datetime.strftime(datetime.now(), "%y%m%d")
OUT_FNAME = f"elections_germany.{TIMESTAMP}.json"

def get_metadata(base_title):
    try:
        date_text, kind, territory = election["title"].split(" ")
        year = date_text.split(".")[-1]
        title = f"{kind} {territory} {year}"
    except ValueError:
        date_text, kind = election["title"].split(" ")
        year = int(date_text.split(".")[-1])
        if kind == "Europawahl":
            territory = "Europawahl"
            title = f"{kind} in Deutschland {year}"
        elif kind == "Bundestagswahl":
            if year >= 1990:
                territory = "Deutschland"
            else:
                territory = "BRD"
            title = f"{kind} {year}"
        elif kind == "Volkskammerwahl":
            territory = "DDR"
            title = f"{kind} {year}"
            
    date = datetime.strptime(date_text, DATE_FORMAT).isoformat()

    return title, date, kind, territory

def select_government(page):
    government = None
    gov_raw = page.find("div", {"class": "regierung"})
    if gov_raw:
        government = [el.get_text() for el in gov_raw.find_all("span")[1:]]
    return government

def select_turnout(page):
    turnout = None
    mod_stoppers = page.find_all("div", {"class": "modStopper"})
    for ms in mod_stoppers:
        if "Wahlbeteiligung" in ms.get_text():
            turnout = float(ms.get_text().strip().split(" ")[1][:-1].replace(",", "."))
    return turnout

def select_party_info(glossary, party):
    if glossary is None:
        return {}
    
    candidates = [a for a in gloss.find_all("div", {"class": "glossarText"}) if party in a.get_text() ]

    rv = {}
    if len(candidates) == 1:
        long_name = candidates[0].get_text().split(":")[1].strip()
        color = candidates[0].previousSibling.previousSibling["style"].split("#")[1][:6]
        rv["long_name"] = long_name
        # #707173 is a placeholder grey color         
        if color != "707173":
            rv["color"] = "#" + color

    return rv
    
def extract_results_from_tables(tables, gloss):
    results = {}
    for t in tables:
        for row in t.find_all("tr", {"class": "row"}):
            party = row.find("td", {"class": "labelshort"}).get_text()
            results[party] = {
                "pct": float(row.find("td", {"class": "perc"}).get_text().replace(",", ".")),
                "votes": int(row.find("td", {"class": "votes"}).get_text().replace(".", ""))
            }
            results[party].update(select_party_info(gloss, party))
    return results
        
# Extract results from image
def extract_results_alt(page, gloss):
    # only small party results are shown in a table
    # find big party results  
    def extract_from_image(page, searchstring):
        els = page.find_all(lambda tag: tag.has_attr("alt") and searchstring in tag["alt"])
        contents = els[0]["alt"]
        contents_1, source = contents.split("Quelle:")
        _, contents_2 = contents_1.split("%:")
        return contents_2.split(";")
        
    try:
        results = extract_from_image(page, "Ergebnis")
    except ValueError:
        results = extract_from_image(page, "Endergebnis")
    except ValueError:
        print(page.find_all(lambda tag: tag.has_attr("alt") and "Ergebnis" in tag["alt"]))
        raise ValueError("No election results could be found on page!")
    rv = {}
    for result in results:
        try:
            party, pct = result.strip().split(" ")
            rv[party] = {
                "pct": float(pct.replace(",", "."))
            }
            rv[party].update(select_party_info(gloss, party))

        except ValueError:
            pass
    if "Andere" in rv.keys():
        del rv["Andere"]
    if "Sonstige" in rv.keys():
        del rv["Sonstige"]
    return rv

def save_results(elections):
    with open(OUT_FNAME, "w") as f:
        json.dump(sorted(elections, key=lambda x: x['title']), f, indent=2, ensure_ascii=False)

elections = []
for i, election in enumerate(election_urls):
    title, date, kind, territory = get_metadata(election["title"])        
    print(str(i) + " - " + title)
    d = requests.get(election["url"])
    page = BeautifulSoup(d.content, 'html.parser')
    
    government = select_government(page)
    turnout = select_turnout(page)

    entry = {}
    entry["title"] = title
    entry["url"] = election["url"]
    entry["date"] = date
    entry["territory"] = territory
    entry["kind"] = kind
    entry["government"] = government
    entry["turnout"] = turnout
    
    try:
        gloss_heading = page.find("h3", {"class": "glossar"})
        gloss = gloss_heading.next_sibling.next_sibling.find("ul")
    except AttributeError:
        print("\tNo glossary here")
        gloss = None
    
    results = {}
    try:
        tableA, tableB = page.find_all("table", {"class": "fivepercentX"})
        results = extract_results_from_tables([tableA, tableB], gloss)
    except ValueError:
        print("\tNo total vote count for parties >5%")
        results = extract_results_alt(page, gloss)
        tableB = page.find("table", {"class": "fivepercent"})
        resultsB = extract_results_from_tables([tableB], gloss) if tableB else {}
        results.update(resultsB)
    entry["results"] = results
    elections.append(entry)
    
    # sanity check (with rounding errors)    
    assert sum([p["pct"] for p in results.values()]) <= 101.0
    
    save_results(elections)
    
    # out of respect
    sleep(.5)
# Out:
# 0 - Landtagswahl Thüringen 2019
# 1 - Landtagswahl Brandenburg 2019
# 2 - Landtagswahl Sachsen 2019
# 3 - Europawahl in Deutschland 2019
# 4 - Bürgerschaftswahl Bremen 2019
# 5 - Landtagswahl Hessen 2018
# 6 - Landtagswahl Bayern 2018
# 7 - Landtagswahl Niedersachsen 2017
# 8 - Bundestagswahl 2017
# 9 - Landtagswahl Nordrhein-Westfalen 2017
# 10 - Landtagswahl Schleswig-Holstein 2017
# 11 - Landtagswahl Saarland 2017
# 12 - Abgeordnetenhauswahl Berlin 2016
# 13 - Landtagswahl Mecklenburg-Vorpommern 2016
# 14 - Landtagswahl Sachsen-Anhalt 2016
# 15 - Landtagswahl Rheinland-Pfalz 2016
# 16 - Landtagswahl Baden-Württemberg 2016
# 17 - Bürgerschaftswahl Bremen 2015
# 18 - Bürgerschaftswahl Hamburg 2015
# 19 - Landtagswahl Thüringen 2014
# 	No total vote count for parties >5%
# 20 - Landtagswahl Brandenburg 2014
# 	No total vote count for parties >5%
# 21 - Landtagswahl Sachsen 2014
# 	No total vote count for parties >5%
# 22 - Europawahl in Deutschland 2014
# 	No total vote count for parties >5%
# 23 - Landtagswahl Hessen 2013
# 	No total vote count for parties >5%
# 24 - Bundestagswahl 2013
# 	No total vote count for parties >5%
# 25 - Landtagswahl Bayern 2013
# 	No total vote count for parties >5%
# 26 - Landtagswahl Niedersachsen 2013
# 	No total vote count for parties >5%
# 27 - Landtagswahl Nordrhein-Westfalen 2012
# 	No total vote count for parties >5%
# 28 - Landtagswahl Schleswig-Holstein 2012
# 	No total vote count for parties >5%
# 29 - Landtagswahl Saarland 2012
# 	No total vote count for parties >5%
# 30 - Abgeordnetenhauswahl Berlin 2011
# 	No total vote count for parties >5%
# 31 - Landtagswahl Mecklenburg-Vorpommern 2011
# 	No total vote count for parties >5%
# 32 - Bürgerschaftswahl Bremen 2011
# 	No total vote count for parties >5%
# 33 - Landtagswahl Rheinland-Pfalz 2011
# 	No total vote count for parties >5%
# 34 - Landtagswahl Baden-Württemberg 2011
# 	No total vote count for parties >5%
# 35 - Landtagswahl Sachsen-Anhalt 2011
# 	No total vote count for parties >5%
# 36 - Bürgerschaftswahl Hamburg 2011
# 	No total vote count for parties >5%
# 37 - Landtagswahl Nordrhein-Westfalen 2010
# 	No total vote count for parties >5%
# 38 - Landtagswahl Schleswig-Holstein 2009
# 	No total vote count for parties >5%
# 39 - Landtagswahl Brandenburg 2009
# 	No total vote count for parties >5%
# 40 - Bundestagswahl 2009
# 	No total vote count for parties >5%
# 41 - Landtagswahl Thüringen 2009
# 	No total vote count for parties >5%
# 42 - Landtagswahl Sachsen 2009
# 	No total vote count for parties >5%
# 43 - Landtagswahl Saarland 2009
# 	No total vote count for parties >5%
# 44 - Europawahl in Deutschland 2009
# 	No total vote count for parties >5%
# 45 - Landtagswahl Hessen 2009
# 	No total vote count for parties >5%
# 46 - Landtagswahl Bayern 2008
# 	No total vote count for parties >5%
# 47 - Bürgerschaftswahl Hamburg 2008
# 	No total vote count for parties >5%
# 48 - Landtagswahl Niedersachsen 2008
# 	No total vote count for parties >5%
# 49 - Landtagswahl Hessen 2008
# 	No total vote count for parties >5%
# 50 - Bürgerschaftswahl Bremen 2007
# 	No total vote count for parties >5%
# 51 - Landtagswahl Mecklenburg-Vorpommern 2006
# 	No total vote count for parties >5%
# 52 - Abgeordnetenhauswahl Berlin 2006
# 	No total vote count for parties >5%
# 53 - Landtagswahl Sachsen-Anhalt 2006
# 	No total vote count for parties >5%
# 54 - Landtagswahl Rheinland-Pfalz 2006
# 	No total vote count for parties >5%
# 55 - Landtagswahl Baden-Württemberg 2006
# 	No total vote count for parties >5%
# 56 - Bundestagswahl 2005
# 	No total vote count for parties >5%
# 57 - Landtagswahl Nordrhein-Westfalen 2005
# 	No total vote count for parties >5%
# 58 - Landtagswahl Schleswig-Holstein 2005
# 	No total vote count for parties >5%
# 59 - Landtagswahl Sachsen 2004
# 	No total vote count for parties >5%
# 60 - Landtagswahl Brandenburg 2004
# 	No total vote count for parties >5%
# 61 - Landtagswahl Saarland 2004
# 	No total vote count for parties >5%
# 62 - Landtagswahl Thüringen 2004
# 	No total vote count for parties >5%
# 63 - Europawahl in Deutschland 2004
# 	No total vote count for parties >5%
# 64 - Bürgerschaftswahl Hamburg 2004
# 	No total vote count for parties >5%
# 65 - Landtagswahl Bayern 2003
# 	No total vote count for parties >5%
# 66 - Bürgerschaftswahl Bremen 2003
# 	No total vote count for parties >5%
# 67 - Landtagswahl Niedersachsen 2003
# 	No total vote count for parties >5%
# 68 - Landtagswahl Hessen 2003
# 	No total vote count for parties >5%
# 69 - Landtagswahl Mecklenburg-Vorpommern 2002
# 	No total vote count for parties >5%
# 70 - Bundestagswahl 2002
# 	No total vote count for parties >5%
# 71 - Landtagswahl Sachsen-Anhalt 2002
# 	No total vote count for parties >5%
# 72 - Abgeordnetenhauswahl Berlin 2001
# 	No total vote count for parties >5%
# 73 - Bürgerschaftswahl Hamburg 2001
# 	No total vote count for parties >5%
# 74 - Landtagswahl Rheinland-Pfalz 2001
# 	No total vote count for parties >5%
# 75 - Landtagswahl Baden-Württemberg 2001
# 	No total vote count for parties >5%
# 76 - Landtagswahl Nordrhein-Westfalen 2000
# 	No total vote count for parties >5%
# 77 - Landtagswahl Schleswig-Holstein 2000
# 	No total vote count for parties >5%
# 78 - Abgeordnetenhauswahl Berlin 1999
# 	No total vote count for parties >5%
# 79 - Landtagswahl Sachsen 1999
# 	No total vote count for parties >5%
# 80 - Landtagswahl Thüringen 1999
# 	No total vote count for parties >5%
# 81 - Landtagswahl Saarland 1999
# 	No total vote count for parties >5%
# 82 - Landtagswahl Brandenburg 1999
# 	No total vote count for parties >5%
# 83 - Europawahl in Deutschland 1999
# 	No total vote count for parties >5%
# 84 - Bürgerschaftswahl Bremen 1999
# 	No total vote count for parties >5%
# 85 - Landtagswahl Hessen 1999
# 	No total vote count for parties >5%
# 86 - Landtagswahl Mecklenburg-Vorpommern 1998
# 	No total vote count for parties >5%
# 87 - Bundestagswahl 1998
# 	No total vote count for parties >5%
# 88 - Landtagswahl Bayern 1998
# 	No total vote count for parties >5%
# 89 - Landtagswahl Sachsen-Anhalt 1998
# 	No total vote count for parties >5%
# 90 - Landtagswahl Niedersachsen 1998
# 	No total vote count for parties >5%
# 91 - Bürgerschaftswahl Hamburg 1997
# 	No total vote count for parties >5%
# 92 - Landtagswahl Schleswig-Holstein 1996
# 	No total vote count for parties >5%
# 93 - Landtagswahl Rheinland-Pfalz 1996
# 	No total vote count for parties >5%
# 94 - Landtagswahl Baden-Württemberg 1996
# 	No total vote count for parties >5%
# 95 - Abgeordnetenhauswahl Berlin 1995
# 	No total vote count for parties >5%
# 96 - Landtagswahl Nordrhein-Westfalen 1995
# 	No total vote count for parties >5%
# 97 - Bürgerschaftswahl Bremen 1995
# 	No total vote count for parties >5%
# 98 - Landtagswahl Hessen 1995
# 	No total vote count for parties >5%
# 99 - Landtagswahl Thüringen 1994
# 	No total vote count for parties >5%
# 100 - Landtagswahl Saarland 1994
# 	No total vote count for parties >5%
# 101 - Landtagswahl Mecklenburg-Vorpommern 1994
# 	No total vote count for parties >5%
# 102 - Bundestagswahl 1994
# 	No total vote count for parties >5%
# 103 - Landtagswahl Bayern 1994
# 	No total vote count for parties >5%
# 104 - Landtagswahl Sachsen 1994
# 	No total vote count for parties >5%
# 105 - Landtagswahl Brandenburg 1994
# 	No total vote count for parties >5%
# 106 - Landtagswahl Sachsen-Anhalt 1994
# 	No total vote count for parties >5%
# 107 - Europawahl in Deutschland 1994
# 	No total vote count for parties >5%
# 108 - Landtagswahl Niedersachsen 1994
# 	No total vote count for parties >5%
# 109 - Bürgerschaftswahl Hamburg 1993
# 	No total vote count for parties >5%
# 110 - Landtagswahl Schleswig-Holstein 1992
# 	No total vote count for parties >5%
# 111 - Landtagswahl Baden-Württemberg 1992
# 	No total vote count for parties >5%
# 112 - Bürgerschaftswahl Bremen 1991
# 	No total vote count for parties >5%
# 113 - Bürgerschaftswahl Hamburg 1991
# 	No total vote count for parties >5%
# 114 - Landtagswahl Rheinland-Pfalz 1991
# 	No total vote count for parties >5%
# 115 - Landtagswahl Hessen 1991
# 	No total vote count for parties >5%
# 116 - Abgeordnetenhauswahl Berlin 1990
# 	No total vote count for parties >5%
# 117 - Bundestagswahl 1990
# 	No total vote count for parties >5%
# 118 - Landtagswahl Thüringen 1990
# 	No total vote count for parties >5%
# 119 - Landtagswahl Sachsen-Anhalt 1990
# 	No total vote count for parties >5%
# 120 - Landtagswahl Sachsen 1990
# 	No total vote count for parties >5%
# 121 - Landtagswahl Mecklenburg-Vorpommern 1990
# 	No total vote count for parties >5%
# 122 - Landtagswahl Bayern 1990
# 	No total vote count for parties >5%
# 123 - Landtagswahl Brandenburg 1990
# 	No total vote count for parties >5%
# 124 - Landtagswahl Nordrhein-Westfalen 1990
# 	No total vote count for parties >5%
# 125 - Landtagswahl Niedersachsen 1990
# 	No total vote count for parties >5%
# 126 - Volkskammerwahl 1990
# 	No total vote count for parties >5%
# 127 - Landtagswahl Saarland 1990
# 	No total vote count for parties >5%
# 128 - Europawahl in Deutschland 1989
# 	No total vote count for parties >5%
# 129 - Abgeordnetenhauswahl Berlin 1989
# 	No total vote count for parties >5%
# 130 - Landtagswahl Schleswig-Holstein 1988
# 	No total vote count for parties >5%
# 131 - Landtagswahl Baden-Württemberg 1988
# 	No total vote count for parties >5%
# 132 - Landtagswahl Schleswig-Holstein 1987
# 	No total vote count for parties >5%
# 133 - Bürgerschaftswahl Bremen 1987
# 	No total vote count for parties >5%
# 134 - Landtagswahl Rheinland-Pfalz 1987
# 	No total vote count for parties >5%
# 135 - Bürgerschaftswahl Hamburg 1987
# 	No total vote count for parties >5%
# 136 - Landtagswahl Hessen 1987
# 	No total vote count for parties >5%
# 137 - Bundestagswahl 1987
# 	No total vote count for parties >5%
# 138 - Bürgerschaftswahl Hamburg 1986
# 	No total vote count for parties >5%
# 139 - Landtagswahl Bayern 1986
# 	No total vote count for parties >5%
# 140 - Landtagswahl Niedersachsen 1986
# 	No total vote count for parties >5%
# 141 - Landtagswahl Nordrhein-Westfalen 1985
# 	No total vote count for parties >5%
# 142 - Landtagswahl Saarland 1985
# 	No total vote count for parties >5%
# 143 - Abgeordnetenhauswahl Berlin 1985
# 	No total vote count for parties >5%
# 144 - Europawahl in Deutschland 1984
# 	No total vote count for parties >5%
# 145 - Landtagswahl Baden-Württemberg 1984
# 	No total vote count for parties >5%
# 146 - Landtagswahl Hessen 1983
# 	No total vote count for parties >5%
# 147 - Bürgerschaftswahl Bremen 1983
# 	No total vote count for parties >5%
# 148 - Landtagswahl Schleswig-Holstein 1983
# 	No total vote count for parties >5%
# 149 - Landtagswahl Rheinland-Pfalz 1983
# 	No total vote count for parties >5%
# 150 - Bundestagswahl 1983
# 	No total vote count for parties >5%
# 151 - Bürgerschaftswahl Hamburg 1982
# 	No total vote count for parties >5%
# 152 - Landtagswahl Bayern 1982
# 	No total vote count for parties >5%
# 153 - Landtagswahl Hessen 1982
# 	No total vote count for parties >5%
# 154 - Bürgerschaftswahl Hamburg 1982
# 	No total vote count for parties >5%
# 155 - Landtagswahl Niedersachsen 1982
# 	No total vote count for parties >5%
# 156 - Abgeordnetenhauswahl Berlin 1981
# 	No total vote count for parties >5%
# 157 - Bundestagswahl 1980
# 	No total vote count for parties >5%
# 158 - Landtagswahl Nordrhein-Westfalen 1980
# 	No total vote count for parties >5%
# 159 - Landtagswahl Saarland 1980
# 	No total vote count for parties >5%
# 160 - Landtagswahl Baden-Württemberg 1980
# 	No total vote count for parties >5%
# 161 - Bürgerschaftswahl Bremen 1979
# 	No total vote count for parties >5%
# 162 - Europawahl in Deutschland 1979
# 	No total vote count for parties >5%
# 163 - Landtagswahl Schleswig-Holstein 1979
# 	No total vote count for parties >5%
# 164 - Landtagswahl Rheinland-Pfalz 1979
# 	No total vote count for parties >5%
# 165 - Abgeordnetenhauswahl Berlin 1979
# 	No total vote count for parties >5%
# 166 - Landtagswahl Bayern 1978
# 	No total vote count for parties >5%
# 167 - Landtagswahl Hessen 1978
# 	No total vote count for parties >5%
# 168 - Landtagswahl Niedersachsen 1978
# 	No total vote count for parties >5%
# 169 - Bürgerschaftswahl Hamburg 1978
# 	No total vote count for parties >5%
# 170 - Bundestagswahl 1976
# 	No total vote count for parties >5%
# 171 - Landtagswahl Baden-Württemberg 1976
# 	No total vote count for parties >5%
# 172 - Bürgerschaftswahl Bremen 1975
# 	No total vote count for parties >5%
# 173 - Landtagswahl Saarland 1975
# 	No total vote count for parties >5%
# 174 - Landtagswahl Nordrhein-Westfalen 1975
# 	No total vote count for parties >5%
# 175 - Landtagswahl Schleswig-Holstein 1975
# 	No total vote count for parties >5%
# 176 - Landtagswahl Rheinland-Pfalz 1975
# 	No total vote count for parties >5%
# 177 - Abgeordnetenhauswahl Berlin 1975
# 	No total vote count for parties >5%
# 178 - Landtagswahl Hessen 1974
# 	No total vote count for parties >5%
# 179 - Landtagswahl Bayern 1974
# 	No total vote count for parties >5%
# 180 - Landtagswahl Niedersachsen 1974
# 	No total vote count for parties >5%
# 181 - Bürgerschaftswahl Hamburg 1974
# 	No total vote count for parties >5%
# 182 - Bundestagswahl 1972
# 	No total vote count for parties >5%
# 183 - Landtagswahl Baden-Württemberg 1972
# 	No total vote count for parties >5%
# 184 - Bürgerschaftswahl Bremen 1971
# 	No total vote count for parties >5%
# 185 - Landtagswahl Schleswig-Holstein 1971
# 	No total vote count for parties >5%
# 186 - Landtagswahl Rheinland-Pfalz 1971
# 	No total vote count for parties >5%
# 187 - Abgeordnetenhauswahl Berlin 1971
# 	No total vote count for parties >5%
# 188 - Landtagswahl Bayern 1970
# 	No total vote count for parties >5%
# 189 - Landtagswahl Hessen 1970
# 	No total vote count for parties >5%
# 190 - Landtagswahl Saarland 1970
# 	No total vote count for parties >5%
# 191 - Landtagswahl Nordrhein-Westfalen 1970
# 	No total vote count for parties >5%
# 192 - Landtagswahl Niedersachsen 1970
# 	No total vote count for parties >5%
# 193 - Bürgerschaftswahl Hamburg 1970
# 	No total vote count for parties >5%
# 194 - Bundestagswahl 1969
# 	No total vote count for parties >5%
# 195 - Landtagswahl Baden-Württemberg 1968
# 	No total vote count for parties >5%
# 196 - Bürgerschaftswahl Bremen 1967
# 	No total vote count for parties >5%
# 197 - Landtagswahl Niedersachsen 1967
# 	No total vote count for parties >5%
# 198 - Landtagswahl Schleswig-Holstein 1967
# 	No total vote count for parties >5%
# 199 - Landtagswahl Rheinland-Pfalz 1967
# 	No total vote count for parties >5%
# 200 - Abgeordnetenhauswahl Berlin 1967
# 	No total vote count for parties >5%
# 201 - Landtagswahl Bayern 1966
# 	No total vote count for parties >5%
# 202 - Landtagswahl Hessen 1966
# 	No total vote count for parties >5%
# 203 - Landtagswahl Nordrhein-Westfalen 1966
# 	No total vote count for parties >5%
# 204 - Bürgerschaftswahl Hamburg 1966
# 	No total vote count for parties >5%
# 205 - Bundestagswahl 1965
# 	No total vote count for parties >5%
# 206 - Landtagswahl Saarland 1965
# 	No total vote count for parties >5%
# 207 - Landtagswahl Baden-Württemberg 1964
# 	No total vote count for parties >5%
# 208 - Bürgerschaftswahl Bremen 1963
# 	No total vote count for parties >5%
# 209 - Landtagswahl Niedersachsen 1963
# 	No total vote count for parties >5%
# 210 - Landtagswahl Rheinland-Pfalz 1963
# 	No total vote count for parties >5%
# 211 - Abgeordnetenhauswahl Berlin 1963
# 	No total vote count for parties >5%
# 212 - Landtagswahl Bayern 1962
# 	No total vote count for parties >5%
# 213 - Landtagswahl Hessen 1962
# 	No total vote count for parties >5%
# 214 - Landtagswahl Schleswig-Holstein 1962
# 	No total vote count for parties >5%
# 215 - Landtagswahl Nordrhein-Westfalen 1962
# 	No total vote count for parties >5%
# 216 - Bürgerschaftswahl Hamburg 1961
# 	No total vote count for parties >5%
# 217 - Bundestagswahl 1961
# 	No total vote count for parties >5%
# 218 - Landtagswahl Saarland 1960
# 	No total vote count for parties >5%
# 219 - Landtagswahl Baden-Württemberg 1960
# 	No total vote count for parties >5%
# 220 - Bürgerschaftswahl Bremen 1959
# 	No total vote count for parties >5%
# 221 - Landtagswahl Rheinland-Pfalz 1959
# 	No total vote count for parties >5%
# 222 - Landtagswahl Niedersachsen 1959
# 	No total vote count for parties >5%
# 223 - Abgeordnetenhauswahl Berlin 1958
# 	No total vote count for parties >5%
# 224 - Landtagswahl Hessen 1958
# 	No total vote count for parties >5%
# 225 - Landtagswahl Bayern 1958
# 	No total vote count for parties >5%
# 226 - Landtagswahl Schleswig-Holstein 1958
# 	No total vote count for parties >5%
# 227 - Landtagswahl Nordrhein-Westfalen 1958
# 	No total vote count for parties >5%
# 228 - Bürgerschaftswahl Hamburg 1957
# 	No total vote count for parties >5%
# 229 - Bundestagswahl 1957
# 	No total vote count for parties >5%
# 230 - Landtagswahl Baden-Württemberg 1956
# 	No total vote count for parties >5%
# 231 - Landtagswahl Saarland 1955
# 	No total vote count for parties >5%
# 232 - Bürgerschaftswahl Bremen 1955
# 	No total vote count for parties >5%
# 233 - Landtagswahl Rheinland-Pfalz 1955
# 	No total vote count for parties >5%
# 234 - Landtagswahl Niedersachsen 1955
# 	No total vote count for parties >5%
# 235 - Abgeordnetenhauswahl Berlin 1954
# 	No total vote count for parties >5%
# 236 - Landtagswahl Hessen 1954
# 	No total vote count for parties >5%
# 237 - Landtagswahl Bayern 1954
# 	No total vote count for parties >5%
# 238 - Landtagswahl Schleswig-Holstein 1954
# 	No total vote count for parties >5%
# 239 - Landtagswahl Nordrhein-Westfalen 1954
# 	No total vote count for parties >5%
# 240 - Bürgerschaftswahl Hamburg 1953
# 	No total vote count for parties >5%
# 241 - Bundestagswahl 1953
# 	No total vote count for parties >5%
# 242 - Landtagswahl Saarland 1952
# 	No total vote count for parties >5%
# 243 - Landtagswahl Baden-Württemberg 1952
# 	No total vote count for parties >5%
# 244 - Bürgerschaftswahl Bremen 1951
# 	No total vote count for parties >5%
# 245 - Landtagswahl Niedersachsen 1951
# 	No total vote count for parties >5%
# 246 - Landtagswahl Rheinland-Pfalz 1951
# 	No total vote count for parties >5%
# 247 - Abgeordnetenhauswahl Berlin 1950
# 	No total vote count for parties >5%
# 248 - Landtagswahl Bayern 1950
# 	No total vote count for parties >5%
# 249 - Landtagswahl Hessen 1950
# 	No total vote count for parties >5%
# 250 - Landtagswahl Württemberg-Baden 1950
# 	No total vote count for parties >5%
# 251 - Landtagswahl Schleswig-Holstein 1950
# 	No total vote count for parties >5%
# 252 - Landtagswahl Nordrhein-Westfalen 1950
# 	No total vote count for parties >5%
# 253 - Bürgerschaftswahl Hamburg 1949
# 	No total vote count for parties >5%
# 254 - Bundestagswahl 1949
# 	No total vote count for parties >5%
# 255 - Abgeordnetenhauswahl Berlin 1948
# 	No glossary here
# 	No total vote count for parties >5%
# 256 - Bürgerschaftswahl Bremen 1947
# 	No total vote count for parties >5%
# 257 - Landtagswahl Saarland 1947
# 	No total vote count for parties >5%
# 258 - Landtagswahl Württemberg-Hohenzollern 1947
# 	No glossary here
# 	No total vote count for parties >5%
# 259 - Landtagswahl Rheinland-Pfalz 1947
# 	No total vote count for parties >5%
# 260 - Landtagswahl Baden 1947
# 	No glossary here
# 	No total vote count for parties >5%
# 261 - Landtagswahl Schleswig-Holstein 1947
# 	No total vote count for parties >5%
# 262 - Landtagswahl Nordrhein-Westfalen 1947
# 	No total vote count for parties >5%
# 263 - Landtagswahl Niedersachsen 1947
# 	No total vote count for parties >5%
# 264 - Landtagswahl Hessen 1946
# 	No total vote count for parties >5%
# 265 - Landtagswahl Bayern 1946
# 	No glossary here
# 	No total vote count for parties >5%
# 266 - Landtagswahl Württemberg-Baden 1946
# 	No glossary here
# 	No total vote count for parties >5%
# 267 - Abgeordnetenhauswahl Berlin 1946
# 	No glossary here
# 	No total vote count for parties >5%
# 268 - Bürgerschaftswahl Hamburg 1946
# 	No total vote count for parties >5%
# 269 - Bürgerschaftswahl Bremen 1946
# 	No total vote count for parties >5%
